# %%
base = 100
age = 61
gender = True
smoker = True
smokerScale = 2
married = True
nOfOffspring = 3
alcoholic = True
alcoholicScale = 1
preExisitingDiseases = False
preExisitingScale = 9
familyDiseasesScale = 3
familyDiseases = True
bmi = 18.8

if(age <=18 and age>0):
    if(preExisitingDiseases):
        if(preExisitingScale>8):
            base = base - 5
        elif(preExisitingScale<=8 and preExisitingScale>6):
            base = base - 2
    
    
    if(familyDiseases):
        if(familyDiseasesScale>8):
            base = base-5
        elif(familyDiseasesScale<=8 and familyDiseasesScale>6):
            base = base-1
    
    if(bmi>24.9 or bmi < 18.5):
        base = base - 2
print(base)
if(age>18 and age<=60):
    if(preExisitingDiseases):
            if(preExisitingScale>8):
                base = base - 7
            elif(preExisitingScale<=8 and preExisitingScale>6):
                base = base - 3
    print(base)       
        
    if(familyDiseases):
        if(familyDiseasesScale>8):
            base = base - 7
        elif(familyDiseasesScale<=8 and familyDiseasesScale>6):
            base = base-3
    print(base)
    if(bmi>24.9 or bmi < 18.5):
        base = base - 6
    if(smoker):
        if(smokerScale>=2): #0,1,2,3
            base = base - 25
        if(smokerScale<2 and smokerScale>=1):
            base = base -15
    print(base)
    if(alcoholic):
        if(alcoholicScale>=2):
            base = base - 16
        if(alcoholicScale<2 and alcoholicScale>1):
            base = base - 10
        if(alcoholicScale<=1 ):
            base = base - 5
    print(base)
   
if(age>60):
    if(preExisitingDiseases):
            if(preExisitingScale>8):
                base = base - 10
            elif(preExisitingScale<=8 and preExisitingScale>6):
                base = base - 5
    print(base)       
        
    if(familyDiseases):
        if(familyDiseasesScale>8):
            base = base - 10
        elif(familyDiseasesScale<=8 and familyDiseasesScale>6):
            base = base-6
    print(base)
    if(bmi>24.9 or bmi < 18.5):
        base = base - 10
    if(smoker):
        if(smokerScale>=2): #0,1,2,3
            base = base - 35
        if(smokerScale<2 and smokerScale>=1):
            base = base -20
    print(base)
    if(alcoholic):
        if(alcoholicScale>=2):
            base = base - 20
        if(alcoholicScale<2 and alcoholicScale>1):
            base = base - 15
        if(alcoholicScale<=1 ):
            base = base - 7
    print(base)
# Out:
# 100
# 100
# 100
# 65
# 58
